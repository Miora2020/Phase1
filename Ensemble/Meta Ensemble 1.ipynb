# %%
# Import Necessary packages
import pandas as pd
import numpy as np
from sklearn.cross_validation import train_test_split
from sklearn.cross_validation import KFold, cross_val_score
from sklearn.metrics import confusion_matrix,precision_recall_curve,f1_score,auc,roc_auc_score,roc_curve,recall_score,classification_report,accuracy_score
from sklearn.model_selection import GridSearchCV
import warnings
warnings.filterwarnings("ignore")
from keras.models import Model, load_model

""" For Credit Card Data"""

# Import data
weight = pd.read_csv("weight.csv")
test = pd.read_csv('test.csv')
testY=test.iloc[:,-1]
X = weight.iloc[:,:-1]
Y = weight.iloc[:,-1]

# Importing predictions of base classifiers on training data
NN = pd.read_csv("WsmoteNN.csv")
#NN = NN["Class"]
XG = pd.read_csv("WsmoteXG.csv")
#XG = XG["Class"]
RF =pd.read_csv("WAErf.csv")
#RF = RF["Class"]
IF =pd.read_csv("WAEif.csv")

# Initializing weight values
W1 = np.arange(0,1.25,0.25)
W2 = np.arange(0,1.25,0.25)
W3 = np.arange(0,1.25,0.25)
W4 = np.arange(0,1.25,0.25)

# Importing predictions of base classifiers on test data
NNt = pd.read_csv("smoteNN.csv")
#NNt = NNt["Class"]
XGt = pd.read_csv("smoteXG.csv")
#XGt = XGt["Class"]
RFt =pd.read_csv("AErf.csv")
#RFt = RFt["Class"]
IFt =pd.read_csv("AEif.csv")
#IFt = IFt["Class"]

# Training
Predictions = []
for i in W1:
    for j in W2:
        for k in W3:
            for l in W4:
                prediction = ((i*NN)+(j*XG)+(k*RF)+(l*IF))/(i+j+k+l)
                Predictions.append(prediction)
del(Predictions[0])


Pred =[]
for i in range(10):
    Pred.append(Predictions)

# For threshold=0
n1 = []
for j in Pred[0]:
        j[j<=0]=0
        j[j>0]=1
        n1.append(j)
Accuracy = []
f1 = []
for pred in n1:
    acc = accuracy_score(Y,pred)
    f_1 = f1_score(Y,pred)
    Accuracy.append(acc)
    f1.append(f_1)     
print(max(Accuracy))
print(Accuracy.index(max(Accuracy)))
print(max(f1))
print(f1.index(max(f1)))
print(confusion_matrix(Y,n1[f1.index(max(f1))]))
print(classification_report(Y,n1[f1.index(max(f1))]))

# For threshold=0.25
n2 = []
for j in Pred[1]:
        j[j<=0.25]=0
        j[j>0.25]=1
        n2.append(j)
Accuracy = []
f1 = []
for pred in n2:
    acc = accuracy_score(Y,pred)
    f_1 = f1_score(Y,pred)
    Accuracy.append(acc)
    f1.append(f_1)     
print(max(Accuracy))
print(Accuracy.index(max(Accuracy)))
print(max(f1))
print(f1.index(max(f1)))
print(confusion_matrix(Y,n2[f1.index(max(f1))]))
print(classification_report(Y,n2[f1.index(max(f1))]))

# For threshold=0.50
n3 = []
for j in Pred[2]:
        j[j<=0.50]=0
        j[j>0.50]=1
        n3.append(j)
Accuracy = []
f1 = []
for pred in n3:
    acc = accuracy_score(Y,pred)
    f_1 = f1_score(Y,pred)
    Accuracy.append(acc)
    f1.append(f_1)     
print(max(Accuracy))
print(Accuracy.index(max(Accuracy)))
print(max(f1))
print(f1.index(max(f1)))
print(confusion_matrix(Y,n3[f1.index(max(f1))]))
print(classification_report(Y,n3[f1.index(max(f1))]))

# For threshold=0.75
n4 = []
for j in Pred[3]:
        j[j<=0.75]=0
        j[j>0.75]=1
        n4.append(j)
Accuracy = []
f1 = []
for pred in n4:
    acc = accuracy_score(Y,pred)
    f_1 = f1_score(Y,pred)
    Accuracy.append(acc)
    f1.append(f_1)     
print(max(Accuracy))
print(Accuracy.index(max(Accuracy)))
print(max(f1))
print(f1.index(max(f1)))
print(confusion_matrix(Y,n4[f1.index(max(f1))]))
print(classification_report(Y,n4[f1.index(max(f1))]))

# For threshold=1
n5 = []
for j in Pred[4]:
        j[j<=1]=0
        j[j>1]=1
        n5.append(j)
Accuracy = []
f1 = []
for pred in n5:
    acc = accuracy_score(Y,pred)
    f_1 = f1_score(Y,pred)
    Accuracy.append(acc)
    f1.append(f_1)     
print(max(Accuracy))
print(Accuracy.index(max(Accuracy)))
print(max(f1))
print(f1.index(max(f1)))
print(confusion_matrix(Y,n5[f1.index(max(f1))]))
print(classification_report(Y,n5[f1.index(max(f1))]))

# Test Set Prediction
print(accuracy_score(testY,RFt))
print(confusion_matrix(testY,RFt))
print(classification_report(testY,RFt))

"""For The Abalone Data"""
# Import Data
weight = pd.read_csv("weight1.csv")
test = pd.read_csv('test.csv')
X_test = test.iloc[:,:-1]
Y_test = test.iloc[:,-1]
X = weight.iloc[:,:-1]
Y = weight.iloc[:,-1]

# Import Base classifier's predictions
NN = pd.read_csv("WsmoteNN.csv")
NN = NN["Class"]
XG = pd.read_csv("WsmoteXG.csv")
XG = XG["Class"]
RF =pd.read_csv("WAErf.csv")
RF = RF["Class"]
IF =pd.read_csv("WAEisolation.csv")
IF = IF["Class"]

W1 = np.arange(0,1.25,0.25)
W2 = np.arange(0,1.25,0.25)
W3 = np.arange(0,1.25,0.25)
W4 = np.arange(0,1.25,0.25)

# Importing predictions of base classifiers on test data
NNt = pd.read_csv("smoteNN.csv")
NNt = NNt["Class"]
XGt = pd.read_csv("smoteXG.csv")
XGt = XGt["Class"]
RFt =pd.read_csv("AErf.csv")
RFt = RFt["Class"]
IFt =pd.read_csv("AEif.csv")
IFt = IFt["Class"]

# For weight dataset
Predictions = []
for i in W1:
    for j in W2:
        for k in W3:
            for l in W4:
                prediction = ((i*NN)+(j*XG)+(k*RF)+(l*IF))/(i+j+k+l)
                Predictions.append(prediction)
del(Predictions[0])

Pred =[]
for i in range(10):
    Pred.append(Predictions)

# For Threshold=0
n1 = []
for j in Pred[0]:
        j[j<=0]=0
        j[j>0]=1
        n1.append(j)
Accuracy = []
f1 = []
for pred in n1:
    acc = accuracy_score(Y,pred)
    f_1 = f1_score(Y,pred)
    Accuracy.append(acc)
    f1.append(f_1)     
print(max(Accuracy))
print(Accuracy.index(max(Accuracy)))
print(max(f1))
print(f1.index(max(f1)))
print(confusion_matrix(Y,n1[f1.index(max(f1))]))
print(classification_report(Y,n1[f1.index(max(f1))]))

# For Threshold=0.25
n2 = []
for j in Pred[1]:
        j[j<=0.25]=0
        j[j>0.25]=1
        n2.append(j)
Accuracy = []
f1 = []
for pred in n2:
    acc = accuracy_score(Y,pred)
    f_1 = f1_score(Y,pred)
    Accuracy.append(acc)
    f1.append(f_1)     
print(max(Accuracy))
print(Accuracy.index(max(Accuracy)))
print(max(f1))
print(f1.index(max(f1)))
print(confusion_matrix(Y,n2[f1.index(max(f1))]))
print(classification_report(Y,n2[f1.index(max(f1))]))

# For Threshold=0.50
n3 = []
for j in Pred[2]:
        j[j<=0.50]=0
        j[j>0.50]=1
        n3.append(j)
Accuracy = []
f1 = []
for pred in n3:
    acc = accuracy_score(Y,pred)
    f_1 = f1_score(Y,pred)
    Accuracy.append(acc)
    f1.append(f_1)     
print(max(Accuracy))
print(Accuracy.index(max(Accuracy)))
print(max(f1))
print(f1.index(max(f1)))
print(confusion_matrix(Y,n3[f1.index(max(f1))]))
print(classification_report(Y,n3[f1.index(max(f1))]))

# For Threshold=0.75
n4 = []
for j in Pred[3]:
        j[j<=0.75]=0
        j[j>0.75]=1
        n4.append(j)
Accuracy = []
f1 = []
for pred in n4:
    acc = accuracy_score(Y,pred)
    f_1 = f1_score(Y,pred)
    Accuracy.append(acc)
    f1.append(f_1)     
print(max(Accuracy))
print(Accuracy.index(max(Accuracy)))
print(max(f1))
print(f1.index(max(f1)))
print(confusion_matrix(Y,n4[f1.index(max(f1))]))
print(classification_report(Y,n4[f1.index(max(f1))]))

# For Threshold=1
n5 = []
for j in Pred[4]:
        j[j<=1]=0
        j[j>1]=1
        n5.append(j)
Accuracy = []
f1 = []
for pred in n5:
    acc = accuracy_score(Y,pred)
    f_1 = f1_score(Y,pred)
    Accuracy.append(acc)
    f1.append(f_1)     
print(max(Accuracy))
print(Accuracy.index(max(Accuracy)))
print(max(f1))
print(f1.index(max(f1)))
print(confusion_matrix(Y,n5[f1.index(max(f1))]))
print(classification_report(Y,n5[f1.index(max(f1))]))
